# %% [markdown]
# ## Observations and Insights

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np

# Study data files
mouse_metadata_path = "./data/Mouse_metadata.csv"
study_results_path = "./data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single dataset
combined_df = pd.merge(mouse_metadata, study_results,
                       on='Mouse ID',
                       how='inner')

# Display the data table for preview
combined_df = combined_df.rename(columns={'Tumor Volume (mm3)': "Tumor Volume", 'Weight (g)': 'Weight'})
combined_df
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight  Timepoint  Tumor Volume  \
# 0        k403     Ramicane  Male          21      16          0     45.000000
# 1        k403     Ramicane  Male          21      16          5     38.825898
# 2        k403     Ramicane  Male          21      16         10     35.014271
# 3        k403     Ramicane  Male          21      16         15     34.223992
# 4        k403     Ramicane  Male          21      16         20     32.997729
# ...       ...          ...   ...         ...     ...        ...           ...
# 1888     z969     Naftisol  Male           9      30         25     63.145652
# 1889     z969     Naftisol  Male           9      30         30     65.841013
# 1890     z969     Naftisol  Male           9      30         35     69.176246
# 1891     z969     Naftisol  Male           9      30         40     70.314904
# 1892     z969     Naftisol  Male           9      30         45     73.867845
#
#       Metastatic Sites
# ...

# %%
# Checking the number of mice.
total_mice = len(combined_df['Mouse ID'])
total_mice
# Out:
# 1893

# %%
# Getting the duplicate mice by ID number that shows up for Mouse ID and Timepoint. CHECK
mice_duplicates = combined_df[combined_df.duplicated(['Mouse ID', 'Timepoint'])]
mice_duplicates
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight  Timepoint  \
# 909     g989     Propriva  Female          21      26          0
# 911     g989     Propriva  Female          21      26          5
# 913     g989     Propriva  Female          21      26         10
# 915     g989     Propriva  Female          21      26         15
# 917     g989     Propriva  Female          21      26         20
#
#      Tumor Volume  Metastatic Sites
# 909     45.000000                 0
# 911     47.570392                 0
# 913     49.880528                 0
# 915     53.442020                 0
# 917     54.657650                 1

# %%
# Optional: Get all the data for the duplicate mouse ID. 
duplicates = combined_df[combined_df.duplicated(['Mouse ID'])]
duplicates
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight  Timepoint  Tumor Volume  \
# 1        k403     Ramicane  Male          21      16          5     38.825898
# 2        k403     Ramicane  Male          21      16         10     35.014271
# 3        k403     Ramicane  Male          21      16         15     34.223992
# 4        k403     Ramicane  Male          21      16         20     32.997729
# 5        k403     Ramicane  Male          21      16         25     33.464577
# ...       ...          ...   ...         ...     ...        ...           ...
# 1888     z969     Naftisol  Male           9      30         25     63.145652
# 1889     z969     Naftisol  Male           9      30         30     65.841013
# 1890     z969     Naftisol  Male           9      30         35     69.176246
# 1891     z969     Naftisol  Male           9      30         40     70.314904
# 1892     z969     Naftisol  Male           9      30         45     73.867845
#
#       Metastatic Sites
# ...

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.c
clean_df = combined_df.drop_duplicates('Mouse ID')
    
clean_df
# Out:
#      Mouse ID Drug Regimen     Sex  Age_months  Weight  Timepoint  \
# 0        k403     Ramicane    Male          21      16          0
# 10       s185    Capomulin  Female           3      17          0
# 20       x401    Capomulin  Female          16      15          0
# 30       m601    Capomulin    Male          22      17          0
# 40       g791     Ramicane    Male          11      16          0
# ...       ...          ...     ...         ...     ...        ...
# 1858     z314     Stelasyn  Female          21      28          0
# 1860     z435     Propriva  Female          12      26          0
# 1863     z581    Infubinol  Female          24      25          0
# 1873     z795     Naftisol  Female          13      29          0
# 1883     z969     Naftisol    Male           9      30          0
#
#       Tumor Volume  Metastatic Sites
# 0             45.0                 0
# 10            45.0                 0
# 20            45.0                 0
# ...

# %%
# Checking the number of mice in the clean DataFrame.
total_mice_clean = len(clean_df['Mouse ID'])
total_mice_clean
clean_df = clean_df.rename(columns={'Tumor Volume (mm3)': "Tumor Volume"})

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# Use groupby and summary statistical methods to calculate the following properties of each drug regimen: 
# mean, median, variance, standard deviation, and SEM of the tumor volume. 

mean = combined_df.groupby('Drug Regimen')['Tumor Volume'].mean().round(2)
median = combined_df.groupby('Drug Regimen')['Tumor Volume'].mean().round(2)
variance =  combined_df.groupby('Drug Regimen')['Tumor Volume'].var().round(2)
std_dev = combined_df.groupby('Drug Regimen')['Tumor Volume'].std().round(2)
sem = combined_df.groupby('Drug Regimen')['Tumor Volume'].sem().round(2)
regimen = combined_df.groupby('Drug Regimen')['Tumor Volume'].nunique()
# Assemble the resulting series into a single summary dataframe.

#mean = mean.tolist()
#median = median.tolist()
#variance = variance.tolist()
#std_dev = std_dev.tolist()
#sem = sem.tolist()

sum_stats_dict = {'Mean': mean,
                 'Median': median,
                 'Variance': variance,
                 'Standard Deviation': std_dev,
                 'Standard Error or Measurement': sem}
                 #'Drug Regimen': regimen}

summary_stats_df = pd.DataFrame(sum_stats_dict)

summary_stats_df
# Out:
#                Mean  Median  Variance  Standard Deviation  \
# Drug Regimen
# Capomulin     40.68   40.68     24.95                4.99
# Ceftamin      52.59   52.59     39.29                6.27
# Infubinol     52.88   52.88     43.13                6.57
# Ketapril      55.24   55.24     68.55                8.28
# Naftisol      54.33   54.33     66.17                8.13
# Placebo       54.03   54.03     61.17                7.82
# Propriva      52.32   52.32     42.35                6.51
# Ramicane      40.22   40.22     23.49                4.85
# Stelasyn      54.23   54.23     59.45                7.71
# Zoniferol     53.24   53.24     48.53                6.97
#
#               Standard Error or Measurement
# Drug Regimen
# Capomulin                              0.33
# Ceftamin                               0.47
# Infubinol                              0.49
# Ketapril                               0.60
# Naftisol                               0.60
# ...

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen)

# Using the aggregation method, produce the same summary statistics in a single line
sum_stats_df = combined_df.groupby('Drug Regimen').agg({'Tumor Volume': ['mean', 'median', 'var', 'std', 'sem']})
                                                                        
sum_stats_df
# Out:
#              Tumor Volume
#                      mean     median        var       std       sem
# Drug Regimen
# Capomulin       40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin        52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol       52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril        55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol        54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo         54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva        52.322552  50.854632  42.351070  6.507770  0.512884
# Ramicane        40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn        54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol       53.236507  51.818479  48.533355  6.966589  0.516398

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of timepoints for all mice tested for each drug regimen using Pandas.

# get count of total timepoints for each drug regimen
timepoint_count = pd.DataFrame(combined_df.groupby(['Drug Regimen']).count().reset_index())

# create df with total timepoints and set the index to drug regimen
timepoint_df = timepoint_count[['Drug Regimen', 'Timepoint']].set_index('Drug Regimen')           
timepoint_df.plot(kind="bar", figsize=(15,3), legend=False)
plt.title('Distribution of Male and Female Mice')
plt.ylabel('Number of Timepoints')
plt.show()

# %%
# Generate a bar plot showing the total number of timepoints for all mice tested for each drug regimen using pyplot.

# create list of drug regimens for x axis labels - list of timepoint count for y axis limit
drug_list = combined_df['Drug Regimen'].unique().tolist()
timepoint_list = timepoint_df['Timepoint'].tolist()

# set x asis labels - set size of bar plot - create bar plot chart
x_axis = drug_list
plt.figure(figsize=(15, 3))
plt.bar(x_axis, timepoint_list, color='b', alpha=0.5)

# set x and y limits
plt.xlim(-0.75, len(x_axis))
plt.ylim(0, max(timepoint_list)+10)

# creat title, x axis label, y label
plt.title('Number of Timepoints for Each Drug Regimen')
plt.xlabel('Drug Regimen')
plt.ylabel('Number of Timepoints')
plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using Pandas
gender_df = pd.DataFrame(combined_df.groupby(['Sex']).count()).reset_index()
gender_df = gender_df[['Sex', 'Mouse ID']]
gender_df.plot(kind='pie', y='Mouse ID', labels=gender_df['Sex'], autopct='%1.2f%%', legend=False)
plt.title('Distribution of Male and Female Mice')
plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot
# create list with total amount of male and female mice
gender_list = combined_df.groupby(['Sex'])['Weight'].count().tolist()


# create pie plot using gender list
plt.pie(gender_list, labels=gender_df['Sex'], colors=['b', 'orange'], autopct='%1.2f%%')

# add title 
plt.title('Distribution of Male and Female Mice')
plt.show()

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin

# Start by getting the last (greatest) timepoint for each mouse:
# find last timepoint for each mouse 
tumor_df = combined_df.loc[combined_df['Timepoint'] == 45]
# set df - sort by drug regimen, mouse id, timepoint
tumor_df = tumor_df.sort_values(['Drug Regimen', 'Mouse ID', 'Timepoint'])

# %%
# Start by getting the last (greatest) timepoint for each mouse
cap_df = tumor_df[tumor_df['Drug Regimen'].isin(["Capomulin"])] #.reset_index()
cap = cap_df.sort_values(['Tumor Volume'], ascending=True).reset_index()
# final timepoints for capo
cap = cap['Tumor Volume']

# Capo - Calculate the IQR and quantitatively determine if there are any potential outliers. 
quartiles = cap.quantile([.25, .5, .75])
lowerq = quartiles[0.25]
upperq = quartiles[0.75]
iqr = upperq-lowerq

print(f"The lower quartile of Capomulin is: {lowerq}")
print(f"The upper quartile of Capomulin is: {upperq}")
print(f"The interquartile range of Capomulin is: {iqr}")
print(f"The the median of Capomulin is: {quartiles[0.5]} ")

lower_bound = lowerq - (1.5*iqr)
upper_bound = upperq + (1.5*iqr)
print(f"Values below {lower_bound} could be outliers.")
print(f"Values above {upper_bound} could be outliers.")
# Out:
# The lower quartile of Capomulin is: 32.37735684
# The upper quartile of Capomulin is: 40.1592203
# The interquartile range of Capomulin is: 7.781863460000004
# The the median of Capomulin is: 37.31184577
# Values below 20.70456164999999 could be outliers.
# Values above 51.83201549 could be outliers.

# %%
# Ramicane
# Start by getting the last (greatest) timepoint for each mouse
ram_df = tumor_df[tumor_df['Drug Regimen'].isin(['Ramicane'])] #.reset_index()
ram = ram_df.sort_values(['Tumor Volume'], ascending=True).reset_index()
# final timepoints for capo
ram = ram['Tumor Volume']

# Ramicane - Calculate the IQR and quantitatively determine if there are any potential outliers. 
quartiles = cap.quantile([.25, .5, .75])
lowerq = quartiles[0.25]
upperq = quartiles[0.75]
iqr = upperq-lowerq

print(f"The lower quartile of Ramicane is: {lowerq}")
print(f"The upper quartile of Ramicane is: {upperq}")
print(f"The interquartile range of Ramicane is: {iqr}")
print(f"The the median of Ramicane is: {quartiles[0.5]} ")

lower_bound = lowerq - (1.5*iqr)
upper_bound = upperq + (1.5*iqr)
print(f"Values below {lower_bound} could be outliers.")
print(f"Values above {upper_bound} could be outliers.")
# Out:
# The lower quartile of Ramicane is: 32.37735684
# The upper quartile of Ramicane is: 40.1592203
# The interquartile range of Ramicane is: 7.781863460000004
# The the median of Ramicane is: 37.31184577
# Values below 20.70456164999999 could be outliers.
# Values above 51.83201549 could be outliers.

# %%
# Infubinol
# Start by getting the last (greatest) timepoint for each mouse
infu_df = tumor_df[tumor_df['Drug Regimen'].isin(['Infubinol'])] #.reset_index()
infu = infu_df.sort_values(['Tumor Volume'], ascending=True).reset_index()
# final timepoints for capo
infu = infu['Tumor Volume']

# Infubinol - Calculate the IQR and quantitatively determine if there are any potential outliers. 
quartiles = cap.quantile([.25, .5, .75])
lowerq = quartiles[0.25]
upperq = quartiles[0.75]
iqr = upperq-lowerq

print(f"The lower quartile of Infubinol is: {lowerq}")
print(f"The upper quartile of Infubinol is: {upperq}")
print(f"The interquartile range of Infubinol is: {iqr}")
print(f"The the median of Infubinol is: {quartiles[0.5]} ")

lower_bound = lowerq - (1.5*iqr)
upper_bound = upperq + (1.5*iqr)
print(f"Values below {lower_bound} could be outliers.")
print(f"Values above {upper_bound} could be outliers.")
# Out:
# The lower quartile of Infubinol is: 32.37735684
# The upper quartile of Infubinol is: 40.1592203
# The interquartile range of Infubinol is: 7.781863460000004
# The the median of Infubinol is: 37.31184577
# Values below 20.70456164999999 could be outliers.
# Values above 51.83201549 could be outliers.

# %%
# Ceftamin
# Start by getting the last (greatest) timepoint for each mouse
cef_df = tumor_df[tumor_df['Drug Regimen'].isin(['Ceftamin'])] #.reset_index()
cef = cef_df.sort_values(['Tumor Volume'], ascending=True).reset_index()
# final timepoints for capo
cef = cef['Tumor Volume']

# Ceftamine - Calculate the IQR and quantitatively determine if there are any potential outliers. 
quartiles = cap.quantile([.25, .5, .75])
lowerq = quartiles[0.25]
upperq = quartiles[0.75]
iqr = upperq-lowerq

print(f"The lower quartile of Ceftamin is: {lowerq}")
print(f"The upper quartile of Ceftamin is: {upperq}")
print(f"The interquartile range of Ceftamin is: {iqr}")
print(f"The the median of Ceftamin is: {quartiles[0.5]} ")

lower_bound = lowerq - (1.5*iqr)
upper_bound = upperq + (1.5*iqr)
print(f"Values below {lower_bound} could be outliers.")
print(f"Values above {upper_bound} could be outliers.")
# Out:
# The lower quartile of Ceftamin is: 32.37735684
# The upper quartile of Ceftamin is: 40.1592203
# The interquartile range of Ceftamin is: 7.781863460000004
# The the median of Ceftamin is: 37.31184577
# Values below 20.70456164999999 could be outliers.
# Values above 51.83201549 could be outliers.

# %%
# Put treatments into a list for for loop (and later for plot labels)


# Create empty list to fill with tumor vol data (for plotting)


# Calculate the IQR and quantitatively determine if there are any potential outliers. 

    
    # Locate the rows which contain mice on each drug and get the tumor volumes
    
    
    # add subset 
    
    
    # Determine outliers using upper and lower bounds

# %%
# Generate a box plot of the final tumor volume of each mouse across four regimens of interest

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a mouse treated with Capomulin

# %%
# Generate a scatter plot of average tumor volume vs. mouse weight for the Capomulin regimen

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and linear regression model 
# for mouse weight and average tumor volume for the Capomulin regimen
